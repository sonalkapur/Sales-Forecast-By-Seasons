# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcdefaults()

# %%
fig, ax = plt.subplots(figsize=(4,3))
objects = ('Log Reg(Lasso)', 'Log Reg( without Lasso)','SVM', 'Ensemble (Hard V)', 'Ensemble (Soft V)')
y_pos = np.arange(len(objects))
accuracy = [84,86,85,86,86]
width = [0.3,0.3,0.3,0.3,0.3]
a = plt.bar(y_pos, accuracy, align='center', alpha=0.5,width=width)
plt.xticks(y_pos, objects)
plt.ylabel('Accuracy')
plt.title('Accuracy of each model')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
ymin = 70
ymax = 90
ymin, ymax = plt.ylim()
plt.yticks(np.arange(70, 90, step=5))
plt.ylim(70,90)
#a[2].set_color('g')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,4))

 
# data to plot
objects = ('Log Reg(Lasso)', 'Log Reg( without Lasso)', 'SVM', 'Ensemble (Hard V)', 'Ensemble (Soft V)')
y_pos = np.arange(len(objects))
n_groups = 5
means_class0 = (65,71,70,71,71)
means_class1 = (90,91,90,91,91)
 
# create plot
#fig, ax = plt.subplots()
bar_width = 0.35
opacity = 0.8
 
a = rects1 = plt.bar(y_pos, means_class0, bar_width,
                 alpha=0.5,
                 label='Class 0')
  
b =rects2 = plt.bar(y_pos + bar_width, means_class1, bar_width,
                 alpha=0.5,
                 label='Class 1')

#plt.xlabel('Models')
plt.ylabel('F1 Scores')
plt.title('F1 score of each model')
plt.setp(ax.get_xticklabels(), rotation=30, horizontalalignment='right')
plt.xticks(y_pos, objects)
ymin = 65
ymax = 92
ymin, ymax = plt.ylim()
plt.ylim(65,92)
plt.yticks(np.arange(65, 92, step=2))
#plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()
#a[0].set_color('g')
#a[3].set_color('g')
#b[0].set_color('b')
#b[3].set_color('b')
plt.tight_layout()
plt.show()
